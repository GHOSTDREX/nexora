# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("irrigation_prediction.csv")

# %%
df
# Out:
#      Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay     6.14          36.48            0.42
# 1         Silt     6.41          50.56            0.38
# 2        Sandy     7.71          40.07            1.09
# 3         Clay     5.96          12.75            1.56
# 4         Clay     7.76          18.58            0.95
# ...        ...      ...            ...             ...
# 9995      Silt     7.01          26.67            0.86
# 9996      Clay     5.40          49.44            0.90
# 9997     Loamy     4.97          60.63            0.99
# 9998     Loamy     7.12          44.33            1.56
# 9999     Sandy     5.65          62.25            1.48
#
#       Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                        2.17          21.90     31.19      1167.70
# 1                        0.23          36.50     26.01       831.28
# 2                        2.18          41.83     76.41      1844.45
# ...

# %%
print(df.shape)

print("\nALL COLUMNS:")
for i, col in enumerate(df.columns, 1):
    print(i, ":", col)
# Out:
# (10000, 20)
#
# ALL COLUMNS:
# 1 : Soil_Type
# 2 : Soil_pH
# 3 : Soil_Moisture
# 4 : Organic_Carbon
# 5 : Electrical_Conductivity
# 6 : Temperature_C
# 7 : Humidity
# 8 : Rainfall_mm
# 9 : Sunlight_Hours
# 10 : Wind_Speed_kmh
# 11 : Crop_Type
# 12 : Crop_Growth_Stage
# 13 : Season
# 14 : Irrigation_Type
# 15 : Water_Source
# 16 : Field_Area_hectare
# 17 : Mulching_Used
# 18 : Previous_Irrigation_mm
# 19 : Region
# 20 : Irrigation_Need

# %%
print(df.describe(include="all").T)
# Out:
#                            count unique        top  freq        mean  \
# Soil_Type                  10000      4      Sandy  2536         NaN
# Soil_pH                  10000.0    NaN        NaN   NaN    6.487857
# Soil_Moisture            10000.0    NaN        NaN   NaN   36.969207
# Organic_Carbon           10000.0    NaN        NaN   NaN    0.944731
# Electrical_Conductivity  10000.0    NaN        NaN   NaN    1.791963
# Temperature_C            10000.0    NaN        NaN   NaN   26.991423
# Humidity                 10000.0    NaN        NaN   NaN   60.080339
# Rainfall_mm              10000.0    NaN        NaN   NaN  1252.49942
# Sunlight_Hours           10000.0    NaN        NaN   NaN    7.518538
# Wind_Speed_kmh           10000.0    NaN        NaN   NaN   10.163545
# Crop_Type                  10000      6       Rice  1711         NaN
# Crop_Growth_Stage          10000      4    Harvest  2581         NaN
# Season                     10000      3       Rabi  3383         NaN
# ...

# %%
print(df.isnull().sum())
# Out:
# Soil_Type                  0
# Soil_pH                    0
# Soil_Moisture              0
# Organic_Carbon             0
# Electrical_Conductivity    0
# Temperature_C              0
# Humidity                   0
# Rainfall_mm                0
# Sunlight_Hours             0
# Wind_Speed_kmh             0
# Crop_Type                  0
# Crop_Growth_Stage          0
# Season                     0
# Irrigation_Type            0
# Water_Source               0
# Field_Area_hectare         0
# Mulching_Used              0
# Previous_Irrigation_mm     0
# Region                     0
# Irrigation_Need            0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(df.columns.tolist())
# Out:
# ['Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Field_Area_hectare', 'Mulching_Used', 'Previous_Irrigation_mm', 'Region', 'Irrigation_Need']

# %%
print(df["Irrigation_Need"].value_counts())
# Out:
# Irrigation_Need
# Low       5864
# Medium    3800
# High       336
# Name: count, dtype: int64

# %%
print(df["Irrigation_Need"].unique())
# Out:
# ['Low' 'Medium' 'High']

# %%
print(df["Crop_Type"].value_counts())
# Out:
# Crop_Type
# Rice         1711
# Maize        1694
# Sugarcane    1678
# Potato       1663
# Wheat        1659
# Cotton       1595
# Name: count, dtype: int64

# %%
print(df["Crop_Growth_Stage"].value_counts())
# Out:
# Crop_Growth_Stage
# Harvest       2581
# Vegetative    2521
# Flowering     2465
# Sowing        2433
# Name: count, dtype: int64

# %%
print(df["Season"].value_counts())
# Out:
# Season
# Rabi      3383
# Kharif    3362
# Zaid      3255
# Name: count, dtype: int64

# %%
print(df["Region"].value_counts())
# Out:
# Region
# South      2102
# West       2017
# East       1994
# Central    1987
# North      1900
# Name: count, dtype: int64

# %%
print(
    df[df["Crop_Type"].isin(["Rice", "Sugarcane"])]
    ["Crop_Type"]
    .value_counts()
)
# Out:
# Crop_Type
# Rice         1711
# Sugarcane    1678
# Name: count, dtype: int64

# %%
print(df["Crop_Type"].unique())
# Out:
# ['Wheat' 'Maize' 'Cotton' 'Rice' 'Sugarcane' 'Potato']

# %%
print("Irrigation Need Distribution:")
print(df["Irrigation_Need"].value_counts())

print("\nUnique Irrigation Need Values:")
print(df["Irrigation_Need"].unique())
# Out:
# Irrigation Need Distribution:
# Irrigation_Need
# Low       5864
# Medium    3800
# High       336
# Name: count, dtype: int64
#
# Unique Irrigation Need Values:
# ['Low' 'Medium' 'High']

# %%
print("Growth Stage Distribution:")
print(df["Crop_Growth_Stage"].value_counts())
# Out:
# Growth Stage Distribution:
# Crop_Growth_Stage
# Harvest       2581
# Vegetative    2521
# Flowering     2465
# Sowing        2433
# Name: count, dtype: int64

# %%
print("Season Distribution:")
print(df["Season"].value_counts())
# Out:
# Season Distribution:
# Season
# Rabi      3383
# Kharif    3362
# Zaid      3255
# Name: count, dtype: int64

# %%
print("Irrigation Type:")
print(df["Irrigation_Type"].value_counts())

print("\nWater Source:")
print(df["Water_Source"].value_counts())
# Out:
# Irrigation Type:
# Irrigation_Type
# Sprinkler    2527
# Rainfed      2511
# Drip         2495
# Canal        2467
# Name: count, dtype: int64
#
# Water Source:
# Water_Source
# River          2528
# Reservoir      2513
# Rainwater      2497
# Groundwater    2462
# Name: count, dtype: int64

# %%
df["Irrigation_Need"].value_counts()
# Out:
# Irrigation_Need
# Low       5864
# Medium    3800
# High       336
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

target_counts = df["Irrigation_Need"].value_counts()

print(target_counts)

target_counts.plot(
    kind="bar",
    figsize=(8, 5),
    title="Irrigation Need Distribution"
)

plt.xlabel("Irrigation Need")
plt.ylabel("Number of Samples")
plt.xticks(rotation=0)
plt.show()
# Out:
# Irrigation_Need
# Low       5864
# Medium    3800
# High       336
# Name: count, dtype: int64

# %%
crop_irrigation = pd.crosstab(
    df["Crop_Type"],
    df["Irrigation_Need"],
    normalize="index"
) * 100

print(crop_irrigation.round(2))
# Out:
# Irrigation_Need  High    Low  Medium
# Crop_Type
# Cotton           3.45  58.18   38.37
# Maize            4.01  57.62   38.37
# Potato           3.07  57.37   39.57
# Rice             2.57  60.20   37.23
# Sugarcane        3.87  58.82   37.31
# Wheat            3.19  59.61   37.19

# %%
crop_irrigation.plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6),
    title="Irrigation Need Distribution by Crop"
)

plt.xlabel("Crop Type")
plt.ylabel("Percentage (%)")
plt.xticks(rotation=45)
plt.legend(title="Irrigation Need")
plt.show()

# %%
rice_sugarcane = df[
    df["Crop_Type"].isin(["Rice", "Sugarcane"])
].copy()

print(
    pd.crosstab(
        rice_sugarcane["Crop_Type"],
        rice_sugarcane["Irrigation_Need"]
    )
)
# Out:
# Irrigation_Need  High   Low  Medium
# Crop_Type
# Rice               44  1030     637
# Sugarcane          65   987     626

# %%
print(
    pd.crosstab(
        rice_sugarcane["Crop_Type"],
        rice_sugarcane["Irrigation_Need"],
        normalize="index"
    ).round(3) * 100
)
# Out:
# Irrigation_Need  High   Low  Medium
# Crop_Type
# Rice              2.6  60.2    37.2
# Sugarcane         3.9  58.8    37.3

# %%
print(
    rice_sugarcane["Irrigation_Need"].value_counts()
)
# Out:
# Irrigation_Need
# Low       2017
# Medium    1263
# High       109
# Name: count, dtype: int64

# %%
numeric_features = [
    "Soil_pH",
    "Soil_Moisture",
    "Organic_Carbon",
    "Electrical_Conductivity",
    "Temperature_C",
    "Humidity",
    "Rainfall_mm",
    "Sunlight_Hours",
    "Wind_Speed_kmh",
    "Field_Area_hectare",
    "Previous_Irrigation_mm"
]

df.groupby("Irrigation_Need")[numeric_features].mean().round(2)
# Out:
#                  Soil_pH  Soil_Moisture  Organic_Carbon  \
# Irrigation_Need
# High                6.54          19.71            0.96
# Low                 6.49          41.72            0.94
# Medium              6.48          31.16            0.95
#
#                  Electrical_Conductivity  Temperature_C  Humidity  \
# Irrigation_Need
# High                                1.75          32.88     59.31
# Low                                 1.79          25.54     59.97
# Medium                              1.80          28.71     60.32
#
#                  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# Irrigation_Need
# High                  677.83            7.56           13.68
# Low                  1346.28            7.52            9.15
# Medium               1158.60            7.51           11.42
#
#                  Field_Area_hectare  Previous_Irrigation_mm
# Irrigation_Need
# High                           7.67                   61.40
# ...

# %%
rice_sugarcane.groupby(
    ["Crop_Type", "Irrigation_Need"]
)[numeric_features].mean().round(2)
# Out:
#                            Soil_pH  Soil_Moisture  Organic_Carbon  \
# Crop_Type Irrigation_Need
# Rice      High                6.53          18.10            0.94
#           Low                 6.50          41.48            0.94
#           Medium              6.46          30.45            0.95
# Sugarcane High                6.41          20.57            1.00
#           Low                 6.48          42.16            0.95
#           Medium              6.51          31.80            0.98
#
#                            Electrical_Conductivity  Temperature_C  Humidity  \
# Crop_Type Irrigation_Need
# Rice      High                                1.61          32.23     60.02
#           Low                                 1.79          25.79     61.05
#           Medium                              1.81          28.78     60.15
# Sugarcane High                                1.82          32.35     56.69
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.boxplot(
    data=rice_sugarcane,
    x="Irrigation_Need",
    y="Soil_Moisture"
)

plt.title("Soil Moisture vs Irrigation Need")
plt.xlabel("Irrigation Need")
plt.ylabel("Soil Moisture")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.boxplot(
    data=rice_sugarcane,
    x="Irrigation_Need",
    y="Soil_Moisture"
)

plt.title("Soil Moisture vs Irrigation Need")
plt.xlabel("Irrigation Need")
plt.ylabel("Soil Moisture")
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=rice_sugarcane,
    x="Irrigation_Need",
    y="Rainfall_mm"
)

plt.title("Rainfall vs Irrigation Need")
plt.xlabel("Irrigation Need")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
pd.crosstab(
    rice_sugarcane["Crop_Type"],
    rice_sugarcane["Irrigation_Need"],
    normalize="index"
).round(3) * 100
# Out:
# Irrigation_Need  High   Low  Medium
# Crop_Type
# Rice              2.6  60.2    37.2
# Sugarcane         3.9  58.8    37.3

# %%
pd.crosstab(
    rice_sugarcane["Season"],
    rice_sugarcane["Irrigation_Need"],
    normalize="index"
).round(3) * 100
# Out:
# Irrigation_Need  High   Low  Medium
# Season
# Kharif            3.7  57.3    39.0
# Rabi              2.8  61.8    35.4
# Zaid              3.1  59.4    37.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.boxplot(
    data=rice_sugarcane,
    x="Irrigation_Need",
    y="Soil_Moisture",
    ax=axes[0]
)

axes[0].set_title("Soil Moisture vs Irrigation Need")


sns.boxplot(
    data=rice_sugarcane,
    x="Irrigation_Need",
    y="Temperature_C",
    ax=axes[1]
)

axes[1].set_title("Temperature vs Irrigation Need")


sns.boxplot(
    data=rice_sugarcane,
    x="Irrigation_Need",
    y="Rainfall_mm",
    ax=axes[2]
)

axes[2].set_title("Rainfall vs Irrigation Need")

plt.tight_layout()
plt.show()

# %%
numeric_cols = [
    "Soil_pH",
    "Soil_Moisture",
    "Organic_Carbon",
    "Electrical_Conductivity",
    "Temperature_C",
    "Humidity",
    "Rainfall_mm",
    "Sunlight_Hours",
    "Wind_Speed_kmh",
    "Field_Area_hectare",
    "Previous_Irrigation_mm"
]

plt.figure(figsize=(12, 8))

sns.heatmap(
    rice_sugarcane[numeric_cols].corr(),
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Feature Correlation Matrix")
plt.show()

# %%
categorical_cols = [
    "Soil_Type",
    "Crop_Type",
    "Crop_Growth_Stage",
    "Season",
    "Mulching_Used",
    "Region"
]

for col in categorical_cols:

    print("\n" + "=" * 60)
    print(col)

    print(
        pd.crosstab(
            rice_sugarcane[col],
            rice_sugarcane["Irrigation_Need"],
            normalize="index"
        ).round(3) * 100
    )
# Out:
# ...
# Soil_Type
# Irrigation_Need  High   Low  Medium
# Soil_Type
# Clay              3.5  59.2    37.3
# Loamy             3.0  58.8    38.1
# Sandy             3.4  60.1    36.5
# Silt              2.9  59.9    37.1
#
# ...
# Crop_Type
# Irrigation_Need  High   Low  Medium
# Crop_Type
# Rice              2.6  60.2    37.2
# Sugarcane         3.9  58.8    37.3
#
# ...
# Crop_Growth_Stage
# Irrigation_Need    High   Low  Medium
# Crop_Growth_Stage
# Flowering           6.2  34.0    59.7
# Harvest             0.1  83.7    16.2
# Sowing              0.5  83.3    16.2
# Vegetative          6.3  35.3    58.4
#
# ...
# Season
# Irrigation_Need  High   Low  Medium
# Season
# Kharif            3.7  57.3    39.0
# Rabi              2.8  61.8    35.4
# Zaid              3.1  59.4    37.5
#
# ...
# Mulching_Used
# Irrigation_Need  High   Low  Medium
# Mulching_Used
# No                5.4  45.6    49.0
# Yes               1.1  72.9    26.0
#
# ...
# Region
# Irrigation_Need  High   Low  Medium
# Region
# ...

# %%
FEATURES = [
    "Soil_Type",
    "Soil_pH",
    "Soil_Moisture",
    "Organic_Carbon",
    "Electrical_Conductivity",
    "Temperature_C",
    "Humidity",
    "Rainfall_mm",
    "Sunlight_Hours",
    "Wind_Speed_kmh",
    "Crop_Type",
    "Crop_Growth_Stage",
    "Season",
    "Field_Area_hectare",
    "Mulching_Used",
    "Region"
]

TARGET = "Irrigation_Need"

# %%
model_df = rice_sugarcane[FEATURES + [TARGET]].copy()

print(model_df.shape)

print(model_df.head())

print(model_df[TARGET].value_counts())
# Out:
# (3389, 17)
#    Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 5       Silt     5.10          20.50            0.37                     1.43
# 6      Sandy     7.44          22.70            0.59                     2.95
# 9      Loamy     6.26          19.58            0.36                     1.67
# 10      Clay     5.36          11.85            1.48                     2.11
# 12      Clay     6.62          64.11            1.17                     3.25
#
#     Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 5           33.34     62.51       402.92            7.03           13.55
# 6           28.02     58.50       764.95            7.08            7.38
# 9           31.14     74.30      1474.55            8.53           17.68
# 10          35.21     73.29      1943.89            5.26           11.17
# 12          40.91     89.85      2457.89            6.30            6.98
#
# ...

# %%
X = model_df[FEATURES]

y = model_df[TARGET]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (3389, 16)
# y shape: (3389,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", X_train.shape)
print("Testing Samples  :", X_test.shape)
# Out:
# Training Samples : (2711, 16)
# Testing Samples  : (678, 16)

# %%
categorical_features = [
    "Soil_Type",
    "Crop_Type",
    "Crop_Growth_Stage",
    "Season",
    "Mulching_Used",
    "Region"
]

numerical_features = [
    col for col in X.columns
    if col not in categorical_features
]

print(categorical_features)
print(numerical_features)
# Out:
# ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Mulching_Used', 'Region']
# ['Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Field_Area_hectare']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        )
    ],
    remainder="passthrough"
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", DecisionTreeClassifier(
        random_state=42
    ))
])

# %%
dt_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Soil_Type', 'Crop_Type',
#                                                    'Crop_Growth_Stage',
#                                                    'Season', 'Mulching_Used',
#                                                    'Region'])])),
#                 ('classifier', DecisionTreeClassifier(random_state=42))])

# %%
y_pred = dt_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
print("Accuracy:",
      accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9837758112094396
#
#               precision    recall  f1-score   support
#
#         High       1.00      0.77      0.87        22
#          Low       0.99      1.00      0.99       403
#       Medium       0.98      0.98      0.98       253
#
#     accuracy                           0.98       678
#    macro avg       0.99      0.92      0.95       678
# weighted avg       0.98      0.98      0.98       678

# %%
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=dt_model.classes_,
    yticklabels=dt_model.classes_
)

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.title("Decision Tree Confusion Matrix")

plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
print(preprocessor)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['Soil_Type', 'Crop_Type', 'Crop_Growth_Stage',
#                                   'Season', 'Mulching_Used', 'Region'])])

# %%
rf_model = Pipeline([
    (
        "preprocessor",
        preprocessor
    ),
    (
        "classifier",
        RandomForestClassifier(
            n_estimators=300,
            random_state=42,
            class_weight="balanced"
        )
    )
])

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"
)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Soil_Type', 'Crop_Type',
#                                                    'Crop_Growth_Stage',
#                                                    'Season', 'Mulching_Used',
#                                                    'Region'])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=300, random_state=42))])

# %%
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9469026548672567
#
#               precision    recall  f1-score   support
#
#         High       1.00      0.14      0.24        22
#          Low       0.96      1.00      0.98       403
#       Medium       0.92      0.94      0.93       253
#
#     accuracy                           0.95       678
#    macro avg       0.96      0.69      0.72       678
# weighted avg       0.95      0.95      0.94       678

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[  3   0  19]
#  [  0 402   1]
#  [  0  16 237]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=dt_model.classes_,
    yticklabels=dt_model.classes_
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Decision Tree Confusion Matrix")
plt.show()

# %%
feature_names = dt_model.named_steps["preprocessor"].get_feature_names_out()

importance = dt_model.named_steps["classifier"].feature_importances_

importance_df = (
    pd.DataFrame({
        "Feature": feature_names,
        "Importance": importance
    })
    .sort_values("Importance", ascending=False)
)

importance_df.head(20)
# Out:
#                                Feature  Importance
# 24            remainder__Temperature_C    0.163414
# 28           remainder__Wind_Speed_kmh    0.160569
# 21            remainder__Soil_Moisture    0.154020
# 26              remainder__Rainfall_mm    0.145657
# 9    cat__Crop_Growth_Stage_Vegetative    0.097505
# 14              cat__Mulching_Used_Yes    0.087411
# 13               cat__Mulching_Used_No    0.073392
# 6     cat__Crop_Growth_Stage_Flowering    0.057735
# 7       cat__Crop_Growth_Stage_Harvest    0.035731
# 8        cat__Crop_Growth_Stage_Sowing    0.023383
# 0                  cat__Soil_Type_Clay    0.000729
# 29       remainder__Field_Area_hectare    0.000455
# 12                    cat__Season_Zaid    0.000000
# 11                    cat__Season_Rabi    0.000000
# 2                 cat__Soil_Type_Sandy    0.000000
# 27           remainder__Sunlight_Hours    0.000000
# 3                  cat__Soil_Type_Silt    0.000000
# ...

# %%
import joblib

joblib.dump(
    dt_model,
    "irrigation_prediction_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
feature_names = dt_model.named_steps["preprocessor"].get_feature_names_out()

importance = dt_model.named_steps["classifier"].feature_importances_

importance_df = (
    pd.DataFrame({
        "Feature": feature_names,
        "Importance": importance
    })
    .sort_values("Importance", ascending=False)
)

importance_df.head(20)
# Out:
#                                Feature  Importance
# 24            remainder__Temperature_C    0.163414
# 28           remainder__Wind_Speed_kmh    0.160569
# 21            remainder__Soil_Moisture    0.154020
# 26              remainder__Rainfall_mm    0.145657
# 9    cat__Crop_Growth_Stage_Vegetative    0.097505
# 14              cat__Mulching_Used_Yes    0.087411
# 13               cat__Mulching_Used_No    0.073392
# 6     cat__Crop_Growth_Stage_Flowering    0.057735
# 7       cat__Crop_Growth_Stage_Harvest    0.035731
# 8        cat__Crop_Growth_Stage_Sowing    0.023383
# 0                  cat__Soil_Type_Clay    0.000729
# 29       remainder__Field_Area_hectare    0.000455
# 12                    cat__Season_Zaid    0.000000
# 11                    cat__Season_Rabi    0.000000
# 2                 cat__Soil_Type_Sandy    0.000000
# 27           remainder__Sunlight_Hours    0.000000
# 3                  cat__Soil_Type_Silt    0.000000
# ...

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=importance_df.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features")

plt.show()

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\admin\Desktop\Smart-Agriculture-AI\Irrigation Recoommendation

# %%
import joblib

joblib.dump(
    dt_model,
    "irrigation_prediction_model.pkl"
)

print("✅ Latest model saved successfully!")
# Out:
# ✅ Latest model saved successfully!

# %%
import os

print("Current Folder:")
print(os.getcwd())
# Out:
# Current Folder:
# C:\Users\admin\Desktop\Smart-Agriculture-AI\Irrigation Recoommendation

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'irrigation_prediction.csv', 'irrigation_prediction_model.pkl', '_irrigation_prediction.ipynb.ipynb']

# %%
print(X.columns.tolist())
# Out:
# ['Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Field_Area_hectare', 'Mulching_Used', 'Region']

# %%
print(df.columns.tolist())
# Out:
# ['Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Field_Area_hectare', 'Mulching_Used', 'Previous_Irrigation_mm', 'Region', 'Irrigation_Need']
